# %% [markdown]
# # BA 860 Assignment 3 Digital Attribution at W.M. Winters
#
# **Teammates**
# - Renata Halim
# - Xinyi (Esme) Li
# - Xin (Ashley) Su

# %% [markdown]
# ## **Assignment**

# %% [markdown]
# <a id="1"></a>
# ### **1.(30 pts) Compare first-touch vs. last-touch attribution models**

# %% [markdown]
# #### **1a. (10 pts) What is the number of orders attributed to each channel using a last-touch model? What about the number of orders attributed to each channel using a first-touch model? What is the corresponding share of credit from the two attribution models?**
# To answer this question, create a table in the following format (including total at the bottom). The data may contain a different list of channels than the one in the table; use all channels available in the data.
# ![Screenshot 2023-04-26 at 12.35.30.png](data:image/png;base64,...)

# %% [markdown]
# This is the answer for 1a:
# ![1a.png](data:image/png;base64,...)

# %% [markdown]
# #### **1b. (10 pts) In a single bar chart, plot the share of credit (in percentage) for the first- and last- touch attribution models by marketing channel.**

# %% [markdown]
# This is the Answer for 1b:
# ![1b.png](data:image/png;base64,...)

# %% [markdown]
# #### **1c. (10 pts) Compare results from the two attribution model. What would be the consequence to Winters if it allocated its marketing budget entirely based on the last- touch attribution model?**

# %% [markdown]
# Comparing these 2 models, both of them are favor in CPM. However, the last-touch attrtbution model favors more than the first-touch model. If Winters allocated its marketing budget entirely based on the last-touch attribution model, it would heavily prioritize CPM and likely allocate a majority of its marketing budget towards CPM advertising. By relying solely on the last-touch attribution model, Winters may overlook the impact of other marketing channels, such as BUZZ AFFILIATE. This could result in a missed opportunity to optimize its marketing strategy and potentially leave potential customers untapped.
# Therefore, it is important to take into account the results from both attribution models and consider a more holistic approach when allocating the marketing budget.

# %% [markdown]
# <a id="1"></a>
# ### **2.(20 pts) Compare new and old customers**

# %% [markdown]
# #### **2a. (5 pts) What is the average number of days that it takes for a new customer to convert (from the first touchpoint)? What is the average number of days that it takes for an old customer to convert?**

# %% [markdown]
# - Average number of days for a new customer to convert: ~ 5 days (5.43)
# - Average number of days for an old customer to convert: ~ 30 days (30.98)

# %% [markdown]
# #### **2b. (5 pts) What is the average number of touchpoints by new versus old customer’s orders?**
# Hint: Use the Touches variable if available. If not, create the ‘Touches’ variable for the number of
# touchpoints per order. R users can use the add_count() function.

# %% [markdown]
# - Old customers: ~ 6 touchpoints (6.32)
# - New customers ~ 5 touchpoints (5.41)

# %% [markdown]
# #### **2c. (5 pts) What is the average order sales amount by new versus old customer’s orders?**

# %% [markdown]
# - Old customers: ~ 203.70 dollars
# - New customers ~ 265.06 dollars

# %% [markdown]
# #### **2d. (5pts) Summarize how new and old customers differ along these three variables.**

# %% [markdown]
# 1.  The average number of days for a new customer to convert is significantly lower than that of an old customer, suggesting that new customers are more likely to make a purchase shortly after being introduced to the company.
# 2. New customers also tend to have a higher average number of touchpoints per order, indicating that they require more interactions with the company before making a purchase.
# 3. New customers tend to have a lower average sales amount per order than old customers.

# %% [markdown]
# ### **3.(20 pts) Consider the revenue per marketing channel using first-touch attribution.**

# %% [markdown]
# #### **3a.(10 pts) Create a table (as in Q1) containing the average sales per order as well as the total revenue by originator channel.**

# %% [markdown]
# 3a:
# ![3a.png](data:image/png;base64,...)

# %% [markdown]
# ####**3b. (5 pts) What is the total incremental net revenue accruing to Winters by originator channel? Express your answer in a table. Assume that Winters has a gross margin of 40%. Also assume 5% of sales from branded search are incremental, and 10% sales are incremental for the remaining channels.**

# %% [markdown]
# This is the table for 3b:
# ![3b.png](data:image/png;base64,...)

# %% [markdown]
# #### **3c. (5 pts) You just found out that Winters search ad team spent $4,200 on branded search advertising during the time period in the data. What is your advice to the search team based on the calculation above?**

# %% [markdown]
# According to our result in the above result, we can see the total incremental net revenue is 3014 dollars, which is below the money spent 4200 dollars by Winters search ads which means we are having some negative returns on this spent. In contrast, i suggest Winter ad team should spend more on branded search since their net incremental revenue is much more higher than the branded search channel to generate more revenue.

# %% [markdown]
# ### **4.(25 pts) Linear/uniform attribution**
# The linear attribution model divides the attribution share between touches equally. For example, an order with one CPM, one CJ, and one TV touchpoint will have place one third attribution share on each touch. This can be accomplished by using the Touches variable (see Q2) to define a new variable:
# LinearAttributionShare = 1 / Touches

# %% [markdown]
# #### **4a.(10 pts) For each channel, what is the sum of the linear attribution shares? What is the corresponding share of credit (in percentage) according to the linear attribution model? Express your answer in a table like in Q1.**

# %% [markdown]
# The sum of the linear attribution shares is 1627.02. Linear attribution model table:
# ![Screenshot 2023-04-30 at 23.10.57.png](data:image/png;base64,...)

# %% [markdown]
# #### **4b. (10 pts) In a single bar chart, plot the share of credit (in percentage) for all three attribution models: first-touch, last-touch and linear.**

# %% [markdown]
# Bar chart for all three attribution models:
# ![Screenshot 2023-04-30 at 23.12.04.png](data:image/png;base64,...)

# %% [markdown]
# #### **4c.(5 pts) Compare the linear model to the first-touch and last-touch models.**

# %% [markdown]
# Based on the bar chart illustrating three attribution models, it is evident that the CPM channel consistently holds the highest share of credit in all three models. In the Buzz affiliate channel, the last touch model claims a larger share of credit compared to the linear model. Conversely, in the Search Google brand channel, the first touch model has a higher share of credit than the linear model. Besides these top three channels, the remaining channels exhibit relatively lower shares of credit across all three models.

# %% [markdown]
# ### **5.(30 pts) Examine the role of the intermediate (Roster and Assist) touch points.**

# %% [markdown]
# #### **5a. (10 pts) Focusing on the top channels, what is the proportion of each channel’s touchpoints by position name: 1) Originator, 2) Roster, 3) Assist, and 4) Converter. Show your result using a table like the following (with the exact top channels listed below):**
# ![Screenshot 2023-04-26 at 13.10.15.png](data:image/png;base64,...)

# %% [markdown]
# Channels touchpoints by position name table:
# ![Screenshot 2023-05-01 at 10.15.59.png](data:image/png;base64,...)

# %% [markdown]
# #### **5b.(10 pts) In a single bar chart, plot the share in percentage (y-axis) of touchpoint types by marketing channels (x-axis).**

# %% [markdown]
# Bar chart of touchpoint types by marketing channels:
# ![Screenshot 2023-04-30 at 23.16.08.png](data:image/png;base64,...)

# %% [markdown]
# #### **5c.(10 pts) Summarize the touch-point type results. Which channels seem to have relatively more or less of its touchpoints as rosters and assist? Compared with linear attribution, which of these channels would receive too much or too little credit under first- and last- touch attribution?**

# %% [markdown]
# In terms of roster, CPM stands out with a higher proportion of touch points in its channel, while the remaining channels show similar proportions of touch points. Regarding the assist role, Buss Affiliate, CJ, and CPM demonstrate comparable and higher proportions of touch points. On the other hand, Search MSN Brand has a relatively lower credit of touch points. Moreover both Search Google Brand and Search MSN Brand receive a significant amount of credit in the first touch, but they receive little credit in the last touch.

# %% [markdown]
# ## **Appendix**

# %% [markdown]
# ### **Code**

# %%
# importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
from statsmodels.stats.power import tt_ind_solve_power as SolPower

# %%
## Connect to google drive
from google.colab import drive
drive.mount('/content/drive')

## Load the dataset
data_folder = '/content/drive/Shared drives/BA 860/HW3/'
df = pd.read_csv(data_folder+'Winters-Attribution-PS3-MSBA-2023.csv')
df.info()
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7652 entries, 0 to 7651
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7652 non-null   int64
#  1   Orderid           7652 non-null   int64
#  2   Orderdatetime     7652 non-null   object
#  3   Saleamount        7652 non-null   float64
#  4   Newcustomer       7652 non-null   object
#  5   Position          7652 non-null   int64
#  6   Positiondatetime  7652 non-null   object
#  7   Groupname         7652 non-null   object
#  8   Networkname       7652 non-null   object
#  9   Networkid         7652 non-null   object
#  10  Brand             7596 non-null   object
#  11  Positionname      7652 non-null   object
#  12  DaysToConvert     7652 non-null   int64
# ...

# %% [markdown]
# #### 1a.

# %%
# convert "New Customer" value to 0/1
df['Newcustomer'] = (df['Newcustomer'] == 'Y').astype('int')
del df['Newcustomer']
df.head()
# Out:
#    Unnamed: 0   Orderid Orderdatetime  Saleamount  Position Positiondatetime  \
# 0           1  11634052  5/1/12 04:24       341.5         1     5/1/12 03:49
# 1           2  11634052  5/1/12 04:24       341.5         0     5/1/12 03:47
# 2           3  11634059  5/1/12 04:08       339.0         2    4/29/12 21:01
# 3           4  11634059  5/1/12 04:08       339.0         1    4/24/12 05:29
# 4           5  11634059  5/1/12 04:08       339.0         0    4/23/12 02:46
#
#              Groupname                            Networkname       Networkid  \
# 0       BUZZ AFFILIATE                     Buzz CPA Affiliate          buzz23
# 1  SEARCH GOOGLE BRAND  G: Medifast Brand Terms > Medifast >          g000793
# 2    PRINT - MAGAZINES                         Medifastok.com  medifastok.com
# 3                  CPM                                Armonix         nar7467
# 4    PRINT - MAGAZINES                         Medifastok.com  medifastok.com
#
# ...

# %%
#Group the DataFrame by Groupname and Position name, and count the values in the counter ID column
grouped_table = df.groupby(['Groupname', 'Positionname'])['Orderid'].count().reset_index()

# Pivot the resulting table to put Position name in the columns
pivot_table = grouped_table.pivot(index='Groupname', columns='Positionname', values='Orderid')

total_row = pivot_table.sum(numeric_only=True, axis=0)
total_row.name = 'Total'
pivot_table = pivot_table.append(total_row)

# Print the pivot table
print(pivot_table)
# Out:
# Positionname             ASSIST  CONVERTER  ORIGINATOR  ROSTER
# Groupname
# BUZZ AFFILIATE            242.0      468.0       215.0   411.0
# CJ                         95.0      234.0        83.0   133.0
# CPM                       823.0      834.0       602.0  2224.0
# DIRECT MAIL                 NaN        NaN         1.0     NaN
# OTHER                       3.0        4.0        20.0    13.0
# PRINT - MAGAZINES           2.0        5.0         4.0     3.0
# SEARCH GOOGLE BRAND        96.0        NaN       495.0   218.0
# SEARCH GOOGLE NON-BRAND     8.0       34.0        48.0    15.0
# SEARCH MSN BRAND           11.0        NaN       124.0    43.0
# SEARCH MSN NON-BRAND        1.0        7.0         5.0     3.0
# SEARCH YAHOO BRAND          NaN        NaN         1.0     2.0
# Social                      NaN        NaN         1.0     1.0
# TV                          5.0       16.0        16.0    12.0
# Uncategorized              12.0       25.0        12.0    22.0
# ...

# %%
df = df[df['Positionname'].isin(['CONVERTER', 'ORIGINATOR'])]

# Group the DataFrame by Groupname and Position name, and count the values in the counter ID column
grouped_table = df.groupby(['Groupname', 'Positionname'])['Orderid'].count().reset_index()

# Pivot the resulting table to put Position name in the columns
pivot_table = grouped_table.pivot(index='Groupname', columns='Positionname', values='Orderid')

# Add a total row to the pivot table
total_row = pivot_table.sum(numeric_only=True, axis=0)
total_row.name = 'Total'
pivot_table = pivot_table.append(total_row)

# Calculate the percentage of each groupname regarding to the two categories of the position name
total_originator = pivot_table['ORIGINATOR'].sum() 
total_converter = pivot_table['CONVERTER'].sum()
pivot_table['ORIGINATOR_credit'] = (pivot_table['ORIGINATOR']) / 1627 
#DF['C_div_by_last'] = DF['C'] / df.iloc[:-1]['C'].values

# Print the pivot table
print(pivot_table)
# Out:
# Positionname             CONVERTER  ORIGINATOR  ORIGINATOR_credit
# Groupname
# BUZZ AFFILIATE               468.0       215.0           0.132145
# CJ                           234.0        83.0           0.051014
# CPM                          834.0       602.0           0.370006
# DIRECT MAIL                    NaN         1.0           0.000615
# OTHER                          4.0        20.0           0.012293
# PRINT - MAGAZINES              5.0         4.0           0.002459
# SEARCH GOOGLE BRAND            NaN       495.0           0.304241
# SEARCH GOOGLE NON-BRAND       34.0        48.0           0.029502
# SEARCH MSN BRAND               NaN       124.0           0.076214
# SEARCH MSN NON-BRAND           7.0         5.0           0.003073
# SEARCH YAHOO BRAND             NaN         1.0           0.000615
# Social                         NaN         1.0           0.000615
# TV                            16.0        16.0           0.009834
# ...

# %%
df = df[df['Positionname'].isin(['ORIGINATOR', 'CONVERTER'])]

# Group by Groupname and Position name and get the count of Counter ID
table = pd.pivot_table(df, values='Orderid', index=['Groupname'], columns=['Positionname'], 
                       aggfunc='count', fill_value=0)# margins=True,)


# Add a column for the percentage of each Groupname regarding to Originator
table['CONVERTER_credit'] = table['CONVERTER'] / 1627 * 100

# Add a column for the percentage of each Groupname regarding to Converter
table['ORIGINATOR_credit'] = table['ORIGINATOR'] / 1627 * 100

# Round the percentages to 2 decimal places
table = table.round(2)

table.loc['Total'] = round(table.sum(),2)

from tabulate import tabulate
head = ["Groupname", "CONVERTER", 'ORIGINATOR', 'CONVERTER_credit', 'ORIGINATOR_credit']
print(tabulate(table, headers=head, tablefmt="pretty"))
# Out:
# +-------------------------+-----------+------------+------------------+-------------------+
# |        Groupname        | CONVERTER | ORIGINATOR | CONVERTER_credit | ORIGINATOR_credit |
# +-------------------------+-----------+------------+------------------+-------------------+
# |     BUZZ AFFILIATE      |   468.0   |   215.0    |      28.76       |       13.21       |
# |           CJ            |   234.0   |    83.0    |      14.38       |        5.1        |
# |           CPM           |   834.0   |   602.0    |      51.26       |       37.0        |
# |       DIRECT MAIL       |    0.0    |    1.0     |       0.0        |       0.06        |
# |          OTHER          |    4.0    |    20.0    |       0.25       |       1.23        |
# |    PRINT - MAGAZINES    |    5.0    |    4.0     |       0.31       |       0.25        |
# |   SEARCH GOOGLE BRAND   |    0.0    |   495.0    |       0.0        |       30.42       |
# ...

# %% [markdown]
# #### 1b.

# %%
df = df[df['Positionname'].isin(['ORIGINATOR', 'CONVERTER'])]

# Group by Groupname and Position name and get the count of Counter ID
table = pd.pivot_table(df, values='Orderid', index=['Groupname'], columns=['Positionname'], 
                       aggfunc='count', fill_value=0)# margins=True,)


# Add a column for the percentage of each Groupname regarding to Originator
table['CONVERTER_credit'] = table['CONVERTER'] / 1627 * 100

# Add a column for the percentage of each Groupname regarding to Converter
table['ORIGINATOR_credit'] = table['ORIGINATOR'] / 1627 * 100

# Round the percentages to 2 decimal places
table = table.round(2)


from tabulate import tabulate
head = ["Groupname", "CONVERTER", 'ORIGINATOR', 'CONVERTER_credit', 'ORIGINATOR_credit']
print(tabulate(table, headers=head, tablefmt="pretty"))
# Out:
# +-------------------------+-----------+------------+------------------+-------------------+
# |        Groupname        | CONVERTER | ORIGINATOR | CONVERTER_credit | ORIGINATOR_credit |
# +-------------------------+-----------+------------+------------------+-------------------+
# |     BUZZ AFFILIATE      |   468.0   |   215.0    |      28.76       |       13.21       |
# |           CJ            |   234.0   |    83.0    |      14.38       |        5.1        |
# |           CPM           |   834.0   |   602.0    |      51.26       |       37.0        |
# |       DIRECT MAIL       |    0.0    |    1.0     |       0.0        |       0.06        |
# |          OTHER          |    4.0    |    20.0    |       0.25       |       1.23        |
# |    PRINT - MAGAZINES    |    5.0    |    4.0     |       0.31       |       0.25        |
# |   SEARCH GOOGLE BRAND   |    0.0    |   495.0    |       0.0        |       30.42       |
# ...

# %%
df_plot = table[['CONVERTER_credit', 'ORIGINATOR_credit']]

# Plot the bar chart
ax = df_plot.sort_values(["CONVERTER_credit",'ORIGINATOR_credit'],
                         ascending=False).plot(kind='bar', figsize=(10, 10), width = 0.8)
# Set the axis labels and title
ax.set_xlabel('Group Name')
ax.set_ylabel('Percentage')
ax.set_title('Percentage of Groupname with respect to Converter and Originator')
plt.xticks(rotation=80)
#ax.sort_values('Percentage',inplace=True)
#ax.remove('Total')
# Show the plot
plt.show()

# %% [markdown]
# #### 1c.

# %% [markdown]
# #### 2a.

# %%
df2 = pd.read_csv(data_folder+'Winters-Attribution-PS3-MSBA-2023.csv')
df2
# Out:
#       Unnamed: 0   Orderid Orderdatetime  Saleamount Newcustomer  Position  \
# 0              1  11634052  5/1/12 04:24      341.50           Y         1
# 1              2  11634052  5/1/12 04:24      341.50           Y         0
# 2              3  11634059  5/1/12 04:08      339.00           Y         2
# 3              4  11634059  5/1/12 04:08      339.00           Y         1
# 4              5  11634059  5/1/12 04:08      339.00           Y         0
# ...          ...       ...           ...         ...         ...       ...
# 7647       10111  11777500  6/1/12 03:45      265.39           N         4
# 7648       10112  11777500  6/1/12 03:45      265.39           N         3
# 7649       10113  11777500  6/1/12 03:45      265.39           N         2
# 7650       10114  11777500  6/1/12 03:45      265.39           N         1
# 7651       10115  11777500  6/1/12 03:45      265.39           N         0
#
#      Positiondatetime            Groupname  \
# ...

# %%
# filter by new customers and first touchpoint, and compute the mean of Days to Convert
new_customer_conv_time = df2.loc[(df2["Newcustomer"] == "Y") & (df2["Position"] == 0), "DaysToConvert"].mean()

# filter by old customers and first touchpoint, and compute the mean of Days to Convert
old_customer_conv_time = df2.loc[(df2["Newcustomer"] == "N") & (df2["Position"] == 0), "DaysToConvert"].mean()

print("Average number of days for a new customer to convert:", new_customer_conv_time)
print("Average number of days for an old customer to convert:", old_customer_conv_time)
# Out:
# Average number of days for a new customer to convert: 5.436004162330906
# Average number of days for an old customer to convert: 30.97747747747748

# %% [markdown]
# #### 2b.

# %%
# create a new variable "Touches" that counts the number of touchpoints per order
df2["Touches"] = df2.groupby("Orderid")["Position"].transform("count")
                    # transform() method on the grouped data to count the number of times each "Order Id" appears in the "Position" column, 
                    #and returns a Series with the same length as the original DataFrame.

# calculate the average number of touchpoints by new versus old customer's orders
df2.groupby("Newcustomer")["Touches"].mean()
# Out:
# Newcustomer
# N    6.318625
# Y    5.409899
# Name: Touches, dtype: float64

# %% [markdown]
# #### 2c.

# %%
# Group by new customer status and calculate the mean sale amount for each group
df2.groupby("Newcustomer")["Saleamount"].mean()
# Out:
# Newcustomer
# N    203.702146
# Y    265.055805
# Name: Saleamount, dtype: float64

# %% [markdown]
# #### 3a.

# %%
#df = df.rename(columns={'Sale Amount': 'SaleAmount'})
originator_data = df[df['Positionname'] == 'ORIGINATOR']


grouped_data = round(originator_data.groupby('Groupname').Saleamount.agg(['sum','mean']).reset_index(),2)
#print(grouped_data.rename(columns={'sum':'Total_revenue','mean':'AVG_sales'}))
from tabulate import tabulate
head = ["Groupname", "Total_revenue", 'AVG_sales']
print(tabulate(grouped_data, headers=head, tablefmt="pretty", showindex=False))
# Out:
# +-------------------------+---------------+-----------+
# |        Groupname        | Total_revenue | AVG_sales |
# +-------------------------+---------------+-----------+
# |     BUZZ AFFILIATE      |   55068.89    |  256.13   |
# |           CJ            |   20660.03    |  248.92   |
# |           CPM           |   142822.39   |  237.25   |
# |       DIRECT MAIL       |    170.98     |  170.98   |
# |          OTHER          |    4863.34    |  243.17   |
# |    PRINT - MAGAZINES    |    1051.91    |  262.98   |
# |   SEARCH GOOGLE BRAND   |   123167.78   |  248.82   |
# | SEARCH GOOGLE NON-BRAND |   11351.95    |   236.5   |
# |    SEARCH MSN BRAND     |   28629.47    |  230.88   |
# |  SEARCH MSN NON-BRAND   |    1081.49    |   216.3   |
# |   SEARCH YAHOO BRAND    |    258.49     |  258.49   |
# |         Social          |     165.0     |   165.0   |
# |           TV            |    3495.47    |  218.47   |
# |      Uncategorized      |    2237.76    |  186.48   |
# ...

# %% [markdown]
# #### 3b.

# %%
grouped_data['Profit_per_sell'] = grouped_data.apply(lambda row: row['sum']*0.05 
                                 if row['Groupname'] in ['SEARCH GOOGLE BRAND',
                                                         'SEARCH MSN BRAND',
                                                        'SEARCH YAHOO BRAND'] else row['sum']*0.1, axis=1)

# calculate gross margin
grouped_data['Total_Incremental_Net_Revenue'] = grouped_data['Profit_per_sell']*0.4
grouped_data = grouped_data.round(2)
head = ["Group Name", "Total_revenue", 'AVG_sales','Profit_per_sell','Total_Incremental_Net_Revenue']
print(tabulate(grouped_data, headers=head, tablefmt="pretty", showindex=False))
# Out:
# +-------------------------+---------------+-----------+-----------------+-------------------------------+
# |       Group Name        | Total_revenue | AVG_sales | Profit_per_sell | Total_Incremental_Net_Revenue |
# +-------------------------+---------------+-----------+-----------------+-------------------------------+
# |     BUZZ AFFILIATE      |   55068.89    |  256.13   |     5506.89     |            2202.76            |
# |           CJ            |   20660.03    |  248.92   |     2066.0      |             826.4             |
# |           CPM           |   142822.39   |  237.25   |    14282.24     |            5712.9             |
# |       DIRECT MAIL       |    170.98     |  170.98   |      17.1       |             6.84              |
# |          OTHER          |    4863.34    |  243.17   |     486.33      |            194.53             |
# |    PRINT - MAGAZINES    |    1051.91    |  262.98   |     105.19      |             42.08             |
# ...

# %%
#INcremental net revenue for brand channel
branded_channel = 2463.36+572.59+5.17
print(branded_channel)
# Out:
# 3041.1200000000003

# %% [markdown]
# #### 3c.

# %% [markdown]
# #### 4a.

# %%
data = pd.read_csv(data_folder+'Winters-Attribution-PS3-MSBA-2023.csv')
data['touches'] = data.groupby('Orderid')['Orderid'].transform('count')

# %%
data['linear_attribution_share'] = 1 / data['touches']

# %%
#the sum of the linear attribution shares
linear_attribution_channel = data.groupby('Groupname')['linear_attribution_share'].sum().reset_index()
linear_attribution_channel['linear_attribution_share'] = linear_attribution_channel['linear_attribution_share'].round(2)
linear_attribution_channel = linear_attribution_channel.sort_values(by='linear_attribution_share', ascending=False).reset_index(drop=True)

# %%
#total_attribution_share
total_attribution_share = linear_attribution_channel['linear_attribution_share'].sum()
round(total_attribution_share,3)
# Out:
# 1627.02

# %%
table = pd.DataFrame(linear_attribution_channel)
total_row = table.sum(numeric_only=True, axis=0)
total_row.name = 'Total'
table = table.append(total_row)
# Out:
# <ipython-input-71-0dacb6581536>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table = table.append(total_row)

# %%
linear_attribution_channel['share_of_credit'] = (linear_attribution_channel['linear_attribution_share'] / total_attribution_share) * 100
linear_attribution_channel['share_of_credit'] = linear_attribution_channel['share_of_credit'].round(2)
#print(linear_attribution_channel[['Group Name', 'linear_attribution_share', 'share_of_credit']])
linear_attribution_model_table = linear_attribution_channel[['Groupname', 'linear_attribution_share', 'share_of_credit']]

# %%
df_model_table = pd.DataFrame(linear_attribution_model_table.sum(), columns=['Total']).T
linear_attribution_model_table_1 = pd.concat([linear_attribution_model_table, df_model_table])

# %%
pivot_table = pd.pivot_table(linear_attribution_channel, values=["linear_attribution_share", "share_of_credit"], index="Groupname")
total_row = pivot_table.sum(numeric_only=True, axis=0)
pivot_table = pivot_table.sort_values(by='linear_attribution_share', ascending=False)
total_row.name = 'Total'
pivot_table = pivot_table.append(total_row)
pivot_table
# Out:
# <ipython-input-74-d565e35f9dac>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pivot_table = pivot_table.append(total_row)
#                          linear_attribution_share  share_of_credit
# Groupname
# CPM                                        835.33            51.34
# BUZZ AFFILIATE                             322.69            19.83
# SEARCH GOOGLE BRAND                        204.05            12.54
# CJ                                         136.53             8.39
# SEARCH MSN BRAND                            48.22             2.96
# SEARCH GOOGLE NON-BRAND                     30.58             1.88
# Uncategorized                               19.28             1.18
# TV                                          12.15             0.75
# OTHER                                        8.19             0.50
# SEARCH MSN NON-BRAND                         5.41             0.33
# ...

# %% [markdown]
# #### 4b.

# %%
data = pd.DataFrame(data)
first_touch_df = data[data['Position'] == 0]
first_touch_sum = first_touch_df.groupby('Groupname')['touches'].count()
first_touch_percentage = round((first_touch_sum / first_touch_sum.sum()) * 100,2)
first_touch_percentage
# Out:
# Groupname
# BUZZ AFFILIATE             13.21
# CJ                          5.10
# CPM                        37.00
# DIRECT MAIL                 0.06
# OTHER                       1.23
# PRINT - MAGAZINES           0.25
# SEARCH GOOGLE BRAND        30.42
# SEARCH GOOGLE NON-BRAND     2.95
# SEARCH MSN BRAND            7.62
# SEARCH MSN NON-BRAND        0.31
# SEARCH YAHOO BRAND          0.06
# Social                      0.06
# TV                          0.98
# Uncategorized               0.74
# Name: touches, dtype: float64

# %%
last_touch_df = data[data['Positionname'] == 'CONVERTER']
last_touch_sum = last_touch_df.groupby('Groupname')['Orderid'].count()
last_touch_percentage = round((last_touch_sum / last_touch_sum.sum()) * 100,2)
last_touch_percentage
# Out:
# Groupname
# BUZZ AFFILIATE             28.76
# CJ                         14.38
# CPM                        51.26
# OTHER                       0.25
# PRINT - MAGAZINES           0.31
# SEARCH GOOGLE NON-BRAND     2.09
# SEARCH MSN NON-BRAND        0.43
# TV                          0.98
# Uncategorized               1.54
# Name: Orderid, dtype: float64

# %%
channel_sum = data.groupby('Groupname')['linear_attribution_share'].sum()
channel_percentage = (channel_sum / total_attribution_share) * 100
channel_percentage = round(channel_percentage,2)
channel_percentage
# Out:
# Groupname
# BUZZ AFFILIATE             19.83
# CJ                          8.39
# CPM                        51.34
# DIRECT MAIL                 0.02
# OTHER                       0.50
# PRINT - MAGAZINES           0.21
# SEARCH GOOGLE BRAND        12.54
# SEARCH GOOGLE NON-BRAND     1.88
# SEARCH MSN BRAND            2.96
# SEARCH MSN NON-BRAND        0.33
# SEARCH YAHOO BRAND          0.03
# Social                      0.02
# TV                          0.75
# Uncategorized               1.18
# Name: linear_attribution_share, dtype: float64

# %%
attribution_models = pd.DataFrame({
    'First Touch': first_touch_percentage,
    'Last Touch': last_touch_percentage,
    'Linear': channel_percentage
})

# %%
import matplotlib.pyplot as plt
ax = attribution_models.plot.bar(rot=0, figsize=(12, 6))
ax.set_ylabel('Share of Credit (%)')
ax.set_title('Share of Credit by Attribution Model')
ax.set_xlabel('Channel')
ax.tick_params(axis='x', which='both', labelrotation=45)
ax.set_xticklabels(attribution_models.index, rotation=45, ha='right')
# Out:
# [Text(0, 0, 'BUZZ AFFILIATE'),
#  Text(1, 0, 'CJ'),
#  Text(2, 0, 'CPM'),
#  Text(3, 0, 'DIRECT MAIL'),
#  Text(4, 0, 'OTHER'),
#  Text(5, 0, 'PRINT - MAGAZINES'),
#  Text(6, 0, 'SEARCH GOOGLE BRAND'),
#  Text(7, 0, 'SEARCH GOOGLE NON-BRAND'),
#  Text(8, 0, 'SEARCH MSN BRAND'),
#  Text(9, 0, 'SEARCH MSN NON-BRAND'),
#  Text(10, 0, 'SEARCH YAHOO BRAND'),
#  Text(11, 0, 'Social'),
#  Text(12, 0, 'TV'),
#  Text(13, 0, 'Uncategorized')]

# %% [markdown]
# #### 4c.

# %% [markdown]
# #### 5a.

# %%
top_channels = ['BUZZ AFFILIATE', 'CJ', 'CPM', 'SEARCH GOOGLE BRAND', 'SEARCH MSN BRAND', 'TV']
top_channels_df = data[data['Groupname'].isin(top_channels)]
channel_touchpoints_count = top_channels_df.groupby('Groupname')['Positionname'].count()
position_counts = top_channels_df.groupby(['Groupname', 'Positionname'])['Positionname'].count()
position_proportions = position_counts / channel_touchpoints_count
position_proportions_table = position_proportions.unstack(level=-1)
position_proportions_table['Total'] = position_proportions_table.sum(axis=1)
position_proportions_table_1= position_proportions_table.applymap(lambda x: '{:0.2%}'.format(x))

# %%
desired_order = ['ORIGINATOR', 'ROSTER', 'ASSIST','CONVERTER','Total']
position_proportions_table_1= position_proportions_table_1[desired_order]
position_proportions_table_1
# Out:
# Positionname        ORIGINATOR  ROSTER  ASSIST CONVERTER    Total
# Groupname
# BUZZ AFFILIATE          16.09%  30.76%  18.11%    35.03%  100.00%
# CJ                      15.23%  24.40%  17.43%    42.94%  100.00%
# CPM                     13.43%  49.61%  18.36%    18.60%  100.00%
# SEARCH GOOGLE BRAND     61.19%  26.95%  11.87%      nan%  100.00%
# SEARCH MSN BRAND        69.66%  24.16%   6.18%      nan%  100.00%
# TV                      32.65%  24.49%  10.20%    32.65%  100.00%

# %% [markdown]
# #### 5b.

# %%
position_proportions_100 = round((position_counts / channel_touchpoints_count) *100 ,2)
position_proportions_table_100 = position_proportions_100.unstack(level=-1)
position_proportions_table_100['Total'] = position_proportions_table_100.sum(axis=1)
desired_order = ['ORIGINATOR', 'ROSTER', 'ASSIST','CONVERTER','Total']
position_proportions_table_100 = position_proportions_table_100[desired_order]

ax = position_proportions_table_100.plot.bar(rot=0, figsize=(12, 6))
ax.set_ylabel('Share of Touchpoint Types (%)')
ax.set_title('Share of Touchpoint Types by Marketing Channels')
ax.set_xlabel('Marketing Channels')
ax.tick_params(axis='x', which='both', labelrotation=45)
ax.set_xticklabels(position_proportions_table.index, rotation=45, ha='right')
# Out:
# [Text(0, 0, 'BUZZ AFFILIATE'),
#  Text(1, 0, 'CJ'),
#  Text(2, 0, 'CPM'),
#  Text(3, 0, 'SEARCH GOOGLE BRAND'),
#  Text(4, 0, 'SEARCH MSN BRAND'),
#  Text(5, 0, 'TV')]

# %% [markdown]
# #### 5c.
